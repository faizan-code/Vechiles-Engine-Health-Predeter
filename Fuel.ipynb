# %%
# print('Plss Enter amount in percentage  ')
N = float(input('Enter amount of N content '))
CO2 = float(input('Enter amount of CO2'))
# H2o = float(input('Enter amount of H2o'))
# O = float(input('Enter amount of O2'))
CO = float(input('Enter amount of CO'))
HC = float(input('Enter amount of HC'))
# SO2 = float(input('Enter amount of SO2'))

if CO2 <= 12.5 and CO2 > 8.5 and HC <= 1.2 and HC > 0.7 and  N > 62 and N<= 69 and CO <= 1.2 and CO > 0.4:
    import cv2
    import numpy as np

    
    window_name = "window"
    interframe_wait_ms = 50

    cap = cv2.VideoCapture('good (2).gif')
    if not cap.isOpened():
        print("Error: Could not open video.")
        exit()

    cv2.namedWindow(window_name, cv2.WND_PROP_FULLSCREEN)
    cv2.setWindowProperty(window_name, cv2.WND_PROP_FULLSCREEN, cv2.WINDOW_FULLSCREEN)

    while (True):
        ret, frame = cap.read()
        if not ret:
            print("")
            break

        cv2.imshow(window_name, frame)
        if cv2.waitKey(interframe_wait_ms) & 0x7F == ord('q'):
            print("Exit requested.")
            break

    cap.release()
    cv2.destroyAllWindows()
    print('Your engine is at good condition .')

   


elif CO2 <= 8.5  or HC <= 0.7 and N <= 58 or CO <= 0.4:
    import cv2
    import numpy as np


    window_name = "window"
    interframe_wait_ms = 60

    cap = cv2.VideoCapture('giphy.gif')
    if not cap.isOpened():
        print("Error: Could not open video.")
        exit()

    cv2.namedWindow(window_name, cv2.WND_PROP_FULLSCREEN)
    cv2.setWindowProperty(window_name, cv2.WND_PROP_FULLSCREEN, cv2.WINDOW_FULLSCREEN)

    while (True):
        ret, frame = cap.read()
        if not ret:
            print("")
            break

        cv2.imshow(window_name, frame)
        if cv2.waitKey(interframe_wait_ms) & 0x7F == ord('q'):
            print("Exit requested.")
            break

    cap.release()
    cv2.destroyAllWindows()
    print('Your engine is Not burning the Fuel Properly it need servicing ')    


else:
    import cv2
    import numpy as np

    
    window_name = "window"
    interframe_wait_ms = 60

    cap = cv2.VideoCapture('giphy.gif')
    if not cap.isOpened():
        print()
        exit()

    cv2.namedWindow(window_name, cv2.WND_PROP_FULLSCREEN)
    cv2.setWindowProperty(window_name, cv2.WND_PROP_FULLSCREEN, cv2.WINDOW_FULLSCREEN)

    while (True):
        ret, frame = cap.read()
        if not ret:
            print()
            break

        cv2.imshow(window_name, frame)
        if cv2.waitKey(interframe_wait_ms) & 0x7F == ord('q'):
            print("Exit requested.")
            break

    cap.release()
    cv2.destroyAllWindows()
    print('Your engine is producing huge amount pollutants and thus consuming lots of fule ')
# Out:
# Enter amount of N content 66
# Enter amount of CO212
# Enter amount of CO0.8
# Enter amount of HC0.8
#
# Your engine is at good condition .

# %% [markdown]
# # GIS
